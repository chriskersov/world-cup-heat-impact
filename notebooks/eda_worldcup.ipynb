# %% [markdown]
# # FIFA World Cup — Exploratory Data Analysis (1930–2022)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid', palette='muted', font_scale=1.05)
# %matplotlib inline
plt.rcParams['figure.dpi'] = 120
plt.rcParams['savefig.bbox'] = 'tight'

# %%
df = pd.read_csv('../data/fifa_world_cup_matches_1930_2022.csv', parse_dates=['Date'])
df.head()
# Out:
#    Year       Date Host_Country   Host_City        Stage      Home_Team  \
# 0  1930 1930-07-13      Uruguay  Montevideo  Group Stage         France
# 1  1930 1930-07-13      Uruguay  Montevideo  Group Stage  United States
# 2  1930 1930-07-14      Uruguay  Montevideo  Group Stage        Romania
# 3  1930 1930-07-14      Uruguay  Montevideo  Group Stage     Yugoslavia
# 4  1930 1930-07-15      Uruguay  Montevideo  Group Stage      Argentina
#
#   Away_Team  Home_Score  Away_Score  Penalties  Penalties_Home_Score  \
# 0    Mexico           4           1          0                     0
# 1   Belgium           3           0          0                     0
# 2      Peru           3           1          0                     0
# 3    Brazil           2           1          0                     0
# 4    France           1           0          0                     0
#
#    Penalties_Away_Score         Winner  Draw
# 0                     0         France     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  964 non-null    int64
#  1   Date                  964 non-null    datetime64[us]
#  2   Host_Country          964 non-null    str
#  3   Host_City             964 non-null    str
#  4   Stage                 964 non-null    str
#  5   Home_Team             964 non-null    str
#  6   Away_Team             964 non-null    str
#  7   Home_Score            964 non-null    int64
#  8   Away_Score            964 non-null    int64
#  9   Penalties             964 non-null    int64
#  10  Penalties_Home_Score  964 non-null    int64
#  11  Penalties_Away_Score  964 non-null    int64
#  12  Winner                785 non-null    str
#  13  Draw                  964 non-null    int64
# dtypes: datetime64[us](1), int64(7), str(6)
# memory usage: 105.6 KB

# %%
df.describe(include='all').T
# Out:
#                       count unique          top freq  \
# Year                  964.0    NaN          NaN  NaN
# Date                    964    NaN          NaN  NaN
# Host_Country            964     18       Brazil   86
# Host_City               964    172  Mexico City   23
# Stage                   964      8  Group Stage  711
# Home_Team               964     81       Brazil   86
# Away_Team               964     85       Mexico   41
# Home_Score            964.0    NaN          NaN  NaN
# Away_Score            964.0    NaN          NaN  NaN
# Penalties             964.0    NaN          NaN  NaN
# Penalties_Home_Score  964.0    NaN          NaN  NaN
# Penalties_Away_Score  964.0    NaN          NaN  NaN
# Winner                  785     64       Brazil   79
# Draw                  964.0    NaN          NaN  NaN
#
#                                             mean                  min  \
# Year                                 1989.244813               1930.0
# ...

# %% [markdown]
# ## 2022 World Cup — EDA

# %%
pd.set_option('display.max_rows', None)
df_2022 = pd.read_csv('../data/worldcup_csvs/worldcup_matches_2022.csv', parse_dates=['Date'], keep_default_na=False)
df_2022
# Out:
#     Year       Date Host_Country  Host_City                 Stage  \
# 0   2022 2022-11-20        Qatar    Al Khor           Group Stage
# 1   2022 2022-11-21        Qatar  Al Rayyan           Group Stage
# 2   2022 2022-11-21        Qatar       Doha           Group Stage
# 3   2022 2022-11-21        Qatar  Al Rayyan           Group Stage
# 4   2022 2022-11-22        Qatar     Lusail           Group Stage
# 5   2022 2022-11-22        Qatar  Al Rayyan           Group Stage
# 6   2022 2022-11-22        Qatar  Al Wakrah           Group Stage
# 7   2022 2022-11-22        Qatar       Doha           Group Stage
# 8   2022 2022-11-23        Qatar  Al Rayyan           Group Stage
# 9   2022 2022-11-23        Qatar  Al Rayyan           Group Stage
# 10  2022 2022-11-23        Qatar    Al Khor           Group Stage
# 11  2022 2022-11-23        Qatar       Doha           Group Stage
# 12  2022 2022-11-24        Qatar     Lusail           Group Stage
# ...
